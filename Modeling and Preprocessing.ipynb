# %%
#Import Libraries
import pandas as pd
import numpy as np

## Modeling & preprocessing import
from pandas.core.frame import Scalar
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder,StandardScaler
from sklearn.preprocessing import StandardScaler, OneHotEncoder, OrdinalEncoder
from sklearn.compose import ColumnTransformer,make_column_transformer,make_column_selector
from sklearn.pipeline import Pipeline, make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn.ensemble import BaggingRegressor
from sklearn.ensemble import RandomForestRegressor

# Boosting
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import accuracy_score


import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load Dataset

# %%
df = pd.read_csv('Data/spotify-2023_2.csv', encoding='latin-1')

# %%
df2 = df.copy()
df2.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
df2.info()
df2.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
# Remove non-numeric characters from the 'streams' column
df['streams'] = df['streams'].str.replace(r'\D', '', regex=True)

# %%
#Coverting streams into float
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')

# %%
# verify our streams column was fixed
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    int64
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
# ...

# %%
## Display the number of columns and rows
df2.shape
print(f'There are {df2.shape [0]} rows and {df2.shape [1]} columns in the dataset.')
# Out:
# There are 953 rows and 24 columns in the dataset.

# %% [markdown]
# # Performing Preprocessing Steps

# %%
# Drop columns
columns_to_drop = ['mode', 'bpm', 'key']
df2.drop(columns_to_drop, axis=1, inplace=True)

# %% [markdown]
# - These columns aren't relevant to our data, so they will be dropped.

# %%
# Check for dulplicates
df2.duplicated().sum()
print (f"There are {df2.duplicated().sum()} duplicates in the dataset")
# Out:
# There are 0 duplicates in the dataset

# %% [markdown]
# ## Handling Missing Values

# %%
# Checking for missing values
df2.isna().sum()
# Out:
# track_name               0
# artist(s)_name           0
# artist_count             0
# released_year            0
# released_month           0
# released_day             0
# in_spotify_playlists     0
# in_spotify_charts        0
# streams                  0
# in_apple_playlists       0
# in_apple_charts          0
# in_deezer_playlists      0
# in_deezer_charts         0
# in_shazam_charts        50
# danceability_%           0
# valence_%                0
# energy_%                 0
# acousticness_%           0
# instrumentalness_%       0
# liveness_%               0
# speechiness_%            0
# dtype: int64

# %% [markdown]
# - We will need to use SimpleImputer in our preprocessing steps to impute missing values.

# %%
# Check for and address any impossible values in numeric columns.
df2.describe(include='number')
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %%
# Check for and address any impossible values in categorical columns.
df2.describe(include='object')
# Out:
#        track_name artist(s)_name    streams in_deezer_playlists  \
# count         953            953        953                 953
# unique        943            645        949                 348
# top      Daylight   Taylor Swift  723894473                   0
# freq            2             34          2                  24
#
#        in_shazam_charts
# count               903
# unique              198
# top                   0
# freq                344

# %% [markdown]
# - We will be dropping track number 574 "Love Grows (Where My Rosemary Goes)" by Edison Lighthouse because this s=track looks like an impossible value.
# - It accumulated a total number of 11053756970173 streams.

# %%
df.drop(574, inplace=True)

# %% [markdown]
# ## Split the Data

# %%
# Define features (X) and target (y)
target = 'streams'
X = df.drop(columns = ['streams']).copy()
y = df[target].copy()
X.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts  in_apple_playlists  in_apple_charts  ...  bpm  key  \
# ...

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %% [markdown]
# ### Making a Preprocessing Pipeline

# %%
# Creating a categorical data selector
cat_selector = make_column_selector(dtype_include = 'object')
cat_selector(X_train)
# Out:
# ['track_name',
#  'artist(s)_name',
#  'in_deezer_playlists',
#  'in_shazam_charts',
#  'key',
#  'mode']

# %% [markdown]
# ### Pipleline for Categorical Data

# %%
# Creating a pipline for handling categorical data

impute_cat = SimpleImputer(strategy='most_frequent')
encoder = OneHotEncoder(handle_unknown='ignore',sparse_output=False)

cat_pipe = make_pipeline(impute_cat,encoder)
cat_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                 ('onehotencoder',
#                  OneHotEncoder(handle_unknown='ignore', sparse_output=False))])

# %% [markdown]
# ### Pipleline for Numerical Data

# %%
# Prepare numeric piepline
num_cols = X_train.select_dtypes('number').columns

mean_imputer = SimpleImputer(strategy="mean")
scaler = StandardScaler()

#Numeric Pipeline
num_pipe = make_pipeline(mean_imputer, scaler)
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %% [markdown]
# ### Tuples

# %%
# Making a cat_tuple for ColumnTransformer
cat_tuple = ('categorical', cat_pipe, cat_selector)
cat_tuple
# Out:
# ('categorical',
#  Pipeline(steps=[('simpleimputer', SimpleImputer(strategy='most_frequent')),
#                  ('onehotencoder',
#                   OneHotEncoder(handle_unknown='ignore', sparse_output=False))]),
#  <sklearn.compose._column_transformer.make_column_selector at 0x16be92a30>)

# %%
# Making a numeric tuple for ColumnTransformer
num_tuple = ('numeric', num_pipe, num_cols)
num_tuple
# Out:
# ('numeric',
#  Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                  ('standardscaler', StandardScaler())]),
#  Index(['artist_count', 'released_year', 'released_month', 'released_day',
#         'in_spotify_playlists', 'in_spotify_charts', 'in_apple_playlists',
#         'in_apple_charts', 'in_deezer_charts', 'bpm', 'danceability_%',
#         'valence_%', 'energy_%', 'acousticness_%', 'instrumentalness_%',
#         'liveness_%', 'speechiness_%'],
#        dtype='object'))

# %%
# Instantiate with verbose_feature_names_out=False
col_transformer = ColumnTransformer([cat_tuple, num_tuple],
                                    verbose_feature_names_out=False)

# Fit on training data
col_transformer.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('categorical',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehotencoder',
#                                                   OneHotEncoder(handle_unknown='ignore',
#                                                                 sparse_output=False))]),
#                                  <sklearn.compose._column_transformer.make_column_selector object at 0x16be92a30>),
#                                 ('numeric',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer()),
#                                                  ('standard...
#                                                   StandardScaler())]),
# ...

# %%
type(col_transformer)
# Out:
# sklearn.compose._column_transformer.ColumnTransformer

# %%
# Transform the training data
X_train_tf = col_transformer.transform(X_train)
# Transform the testing data
X_test_tf = col_transformer.transform(X_test)

# %% [markdown]
# ## Models

# %% [markdown]
# ### Linreg Model

# %%
# Instantiate a linear regression model
linreg = LinearRegression()
# Combine the preprocessing ColumnTransformer and the linear regression model in a Pipeline
linreg_pipe = make_pipeline(col_transformer, linreg)
linreg_pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x16be92a30>),
#                                                  ('numeric',
#                                                   Pipeline(steps=[('simpl...
# ...

# %%
# Fit the model pipeline on the training data
linreg_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x16be92a30>),
#                                                  ('numeric',
#                                                   Pipeline(steps=[('simpl...
# ...

# %% [markdown]
# ### Evaluate the Model

# %%
def regression_metrics(y_true, y_pred, label='', verbose = True, output_dict=False):
  # Get metrics
  mae = mean_absolute_error(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = mean_squared_error(y_true, y_pred, squared=False)
  r_squared = r2_score(y_true, y_pred)
  if verbose == True:
    # Print Result with Label and Header
    header = "-"*60
    print(header, f"Regression Metrics: {label}", header, sep='\n')
    print(f"- MAE = {mae:,.3f}")
    print(f"- MSE = {mse:,.3f}")
    print(f"- RMSE = {rmse:,.3f}")
    print(f"- R^2 = {r_squared:,.3f}")
  if output_dict == True:
      metrics = {'Label':label, 'MAE':mae,
                 'MSE':mse, 'RMSE':rmse, 'R^2':r_squared}
      return metrics

def evaluate_regression(reg, X_train, y_train, X_test, y_test, verbose = True,
                        output_frame=False):
  # Get predictions for training data
  y_train_pred = reg.predict(X_train)

  # Call the helper function to obtain regression metrics for training data
  results_train = regression_metrics(y_train, y_train_pred, verbose = verbose,
                                     output_dict=output_frame,
                                     label='Training Data')
  print()
  # Get predictions for test data
  y_test_pred = reg.predict(X_test)
  # Call the helper function to obtain regression metrics for test data
  results_test = regression_metrics(y_test, y_test_pred, verbose = verbose,
                                  output_dict=output_frame,
                                    label='Test Data' )

  # Store results in a dataframe if ouput_frame is True
  if output_frame:
    results_df = pd.DataFrame([results_train,results_test])
    # Set the label as the index
    results_df = results_df.set_index('Label')
    # Set index.name to none to get a cleaner looking result
    results_df.index.name=None
    # Return the dataframe
    return results_df.round(3)

# %%
# Obtain Model Evulation using custom function
evaluate_regression(linreg_pipe, X_train, y_train, X_test, y_test)
# Out:
# ------------------------------------------------------------
# Regression Metrics: Training Data
# ------------------------------------------------------------
# - MAE = 0.000
# - MSE = 0.000
# - RMSE = 0.000
# - R^2 = 1.000
#
# ------------------------------------------------------------
# Regression Metrics: Test Data
# ------------------------------------------------------------
# - MAE = 205,318,724.407
# - MSE = 81,162,572,279,503,584.000
# - RMSE = 284,890,456.631
# - R^2 = 0.737

# %% [markdown]
# - This model performs relatively well on our testing data
# - The R-squared value of 0.737 suggests that the model explains a substantial proportion (73.7%) of the variability in the dependent variable
# - Will explore using other models to see how they perform

# %% [markdown]
# ### Random Forest Model

# %%
# Instantiate default random forest model
rf = RandomForestRegressor(random_state = 42)
# Model Pipeline
rf_pipe = make_pipeline(col_transformer, rf)
rf_pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x16be92a30>),
#                                                  ('numeric',
#                                                   Pipeline(steps=[('simpl...
# ...

# %%
# Fit the model pipeline on the training data
rf_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x16be92a30>),
#                                                  ('numeric',
#                                                   Pipeline(steps=[('simpl...
# ...

# %% [markdown]
# ### Evaluate the Model

# %%
def regression_metrics(y_true, y_pred, label='', verbose = True, output_dict=False):
  # Get metrics
  mae = mean_absolute_error(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = mean_squared_error(y_true, y_pred, squared=False)
  r_squared = r2_score(y_true, y_pred)
  if verbose == True:
    # Print Result with Label and Header
    header = "-"*60
    print(header, f"Regression Metrics: {label}", header, sep='\n')
    print(f"- MAE = {mae:,.3f}")
    print(f"- MSE = {mse:,.3f}")
    print(f"- RMSE = {rmse:,.3f}")
    print(f"- R^2 = {r_squared:,.3f}")
  if output_dict == True:
      metrics = {'Label':label, 'MAE':mae,
                 'MSE':mse, 'RMSE':rmse, 'R^2':r_squared}
      return metrics

def evaluate_regression(reg, X_train, y_train, X_test, y_test, verbose = True,
                        output_frame=False):
  # Get predictions for training data
  y_train_pred = reg.predict(X_train)

  # Call the helper function to obtain regression metrics for training data
  results_train = regression_metrics(y_train, y_train_pred, verbose = verbose,
                                     output_dict=output_frame,
                                     label='Training Data')
  print()
  # Get predictions for test data
  y_test_pred = reg.predict(X_test)
  # Call the helper function to obtain regression metrics for test data
  results_test = regression_metrics(y_test, y_test_pred, verbose = verbose,
                                  output_dict=output_frame,
                                    label='Test Data' )

  # Store results in a dataframe if ouput_frame is True
  if output_frame:
    results_df = pd.DataFrame([results_train,results_test])
    # Set the label as the index
    results_df = results_df.set_index('Label')
    # Set index.name to none to get a cleaner looking result
    results_df.index.name=None
    # Return the dataframe
    return results_df.round(3)

# %%
# Obtain Model Evulation using custom function
evaluate_regression(rf_pipe, X_train, y_train, X_test, y_test)
# Out:
# ------------------------------------------------------------
# Regression Metrics: Training Data
# ------------------------------------------------------------
# - MAE = 55,332,178.286
# - MSE = 8,494,757,565,746,140.000
# - RMSE = 92,167,009.096
# - R^2 = 0.974
#
# ------------------------------------------------------------
# Regression Metrics: Test Data
# ------------------------------------------------------------
# - MAE = 145,070,758.663
# - MSE = 56,164,223,811,492,784.000
# - RMSE = 236,989,923.439
# - R^2 = 0.818

# %% [markdown]
# - This performed better than our previous model
# - The R-squared value of 0.818 suggests that the model explains a significant proportion of the variability in the dependent variable
# - Would do some tuning to see if we can get a better result

# %% [markdown]
# ## Tuning Random Forest

# %%
# Parameters for tuning
rf_pipe.get_params()
# Out:
# {'memory': None,
#  'steps': [('columntransformer',
#    ColumnTransformer(transformers=[('categorical',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer(strategy='most_frequent')),
#                                                     ('onehotencoder',
#                                                      OneHotEncoder(handle_unknown='ignore',
#                                                                    sparse_output=False))]),
#                                     <sklearn.compose._column_transformer.make_column_selector object at 0x16be92a30>),
#                                    ('numeric',
#                                     Pipeline(steps=[('simpleimputer',
#                                                      SimpleImputer()),
#                                                     ('standard...
#                                                      StandardScaler())]),
# ...

# %%
# Define param grid with options to try
params = {'randomforestregressor__max_depth': [None,10,15,20],
          'randomforestregressor__n_estimators':[10,100,150,200],
          'randomforestregressor__min_samples_leaf':[2,3,4],
          'randomforestregressor__max_features':['sqrt','log2',None],
          'randomforestregressor__oob_score':[True,False],
          }

# %%
# Instantiate the gridsearch
gridsearch = GridSearchCV(rf_pipe, params, n_jobs=-1, cv = 2, verbose=1)
# Fit the gridsearch on training data
gridsearch.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 288 candidates, totalling 576 fits
# GridSearchCV(cv=2,
#              estimator=Pipeline(steps=[('columntransformer',
#                                         ColumnTransformer(transformers=[('categorical',
#                                                                          Pipeline(steps=[('simpleimputer',
#                                                                                           SimpleImputer(strategy='most_frequent')),
#                                                                                          ('onehotencoder',
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse_output=False))]),
# ...

# %%
# Obtain best parameters
gridsearch.best_params_
# Out:
# {'randomforestregressor__max_depth': 10,
#  'randomforestregressor__max_features': None,
#  'randomforestregressor__min_samples_leaf': 2,
#  'randomforestregressor__n_estimators': 200,
#  'randomforestregressor__oob_score': True}

# %%
# Define and refit best model
best_rf = gridsearch.best_estimator_
evaluate_regression(best_rf, X_train, y_train, X_test, y_test)
# Out:
# ------------------------------------------------------------
# Regression Metrics: Training Data
# ------------------------------------------------------------
# - MAE = 68,211,084.993
# - MSE = 12,526,955,437,248,794.000
# - RMSE = 111,923,882.336
# - R^2 = 0.961
#
# ------------------------------------------------------------
# Regression Metrics: Test Data
# ------------------------------------------------------------
# - MAE = 148,837,879.148
# - MSE = 57,438,417,448,048,448.000
# - RMSE = 239,663,133.268
# - R^2 = 0.814

# %% [markdown]
# - Our tuned rf model gave pretty much the same accuracy (81.4%).
# - Our best model would be the random forest model, giving us the best accuracy of 81.8%

# %%
# Instantiate and fit gradient boosting classifier
gb = GradientBoostingRegressor(random_state=42)

# Instantiate with verbose_feature_names_out=False
col_transformer = ColumnTransformer([cat_tuple, num_tuple],
                                    verbose_feature_names_out=False)

# Fit on training data
col_transformer.fit(X_train)

# Model Pipeline
impute_cat = SimpleImputer(strategy='most_frequent')
encoder = OneHotEncoder(handle_unknown='ignore',sparse_output=False)

cat_pipe = make_pipeline(impute_cat,encoder)
cat_pipe
gb_pipe = make_pipeline(col_transformer, gb)
gb_pipe
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x16be92a30>),
#                                                  ('numeric',
#                                                   Pipeline(steps=[('simpl...
# ...

# %%
gb_pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(transformers=[('categorical',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoder',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   <sklearn.compose._column_transformer.make_column_selector object at 0x16be92a30>),
#                                                  ('numeric',
#                                                   Pipeline(steps=[('simpl...
# ...

# %%
def regression_metrics(y_true, y_pred, label='', verbose = True, output_dict=False):
  # Get metrics
  mae = mean_absolute_error(y_true, y_pred)
  mse = mean_squared_error(y_true, y_pred)
  rmse = mean_squared_error(y_true, y_pred, squared=False)
  r_squared = r2_score(y_true, y_pred)
  if verbose == True:
    # Print Result with Label and Header
    header = "-"*60
    print(header, f"Regression Metrics: {label}", header, sep='\n')
    print(f"- MAE = {mae:,.3f}")
    print(f"- MSE = {mse:,.3f}")
    print(f"- RMSE = {rmse:,.3f}")
    print(f"- R^2 = {r_squared:,.3f}")
  if output_dict == True:
      metrics = {'Label':label, 'MAE':mae,
                 'MSE':mse, 'RMSE':rmse, 'R^2':r_squared}
      return metrics

def evaluate_regression(reg, X_train, y_train, X_test, y_test, verbose = True,
                        output_frame=False):
  # Get predictions for training data
  y_train_pred = reg.predict(X_train)

  # Call the helper function to obtain regression metrics for training data
  results_train = regression_metrics(y_train, y_train_pred, verbose = verbose,
                                     output_dict=output_frame,
                                     label='Training Data')
  print()
  # Get predictions for test data
  y_test_pred = reg.predict(X_test)
  # Call the helper function to obtain regression metrics for test data
  results_test = regression_metrics(y_test, y_test_pred, verbose = verbose,
                                  output_dict=output_frame,
                                    label='Test Data' )

  # Store results in a dataframe if ouput_frame is True
  if output_frame:
    results_df = pd.DataFrame([results_train,results_test])
    # Set the label as the index
    results_df = results_df.set_index('Label')
    # Set index.name to none to get a cleaner looking result
    results_df.index.name=None
    # Return the dataframe
    return results_df.round(3)

# %%
# Obtain Model Evulation using custom function
evaluate_regression(gb_pipe, X_train, y_train, X_test, y_test)
# Out:
# ------------------------------------------------------------
# Regression Metrics: Training Data
# ------------------------------------------------------------
# - MAE = 93,887,308.166
# - MSE = 15,318,712,555,693,134.000
# - RMSE = 123,768,786.678
# - R^2 = 0.953
#
# ------------------------------------------------------------
# Regression Metrics: Test Data
# ------------------------------------------------------------
# - MAE = 148,108,583.512
# - MSE = 53,751,403,179,603,832.000
# - RMSE = 231,843,488.543
# - R^2 = 0.826
